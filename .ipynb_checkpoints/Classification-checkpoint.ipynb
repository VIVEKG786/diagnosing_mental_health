# %%
import numpy as np
import pandas as pd
import scipy.stats as st

import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import RandomOverSampler

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,confusion_matrix,classification_report,ConfusionMatrixDisplay

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
SEED = 7

# %% [markdown]
# # Data and Description

# %%
disorder = pd.read_csv('data/Dataset-Mental-Disorders.csv',index_col=0)
disorder.head()
# Out:
#                   Sadness    Euphoric  Exhausted Sleep dissorder Mood Swing  \
# Patient Number
# Patiant-01        Usually      Seldom        NaN       Sometimes        YES
# Patiant-02        Usually      Seldom    Usually       Sometimes         NO
# Patiant-03      Sometimes  Most-Often  Sometimes       Sometimes        YES
# Patiant-04        Usually      Seldom    Usually      Most-Often        YES
# Patiant-05        Usually     Usually  Sometimes       Sometimes         NO
#
#                Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# Patient Number
# Patiant-01                  YES       NO                NO             YES
# Patiant-02                   YES      NO                NO              NO
# Patiant-03                    NO      NO                NO             YES
# Patiant-04                   YES     YES                NO             YES
# Patiant-05                    NO      NO                NO              NO
#
#                Aggressive Response Ignore & Move-On Nervous Break-down  \
# Patient Number
# Patiant-01                      NO               NO                YES
# Patiant-02                      NO               NO                 NO
# Patiant-03                     YES               NO                YES
# Patiant-04                      NO               NO                 NO
# Patiant-05                      NO               NO                YES
#
#                Admit Mistakes Overthinking Sexual Activity Concentration  \
# Patient Number
# Patiant-01                YES          YES       3 From 10     3 From 10
# Patiant-02                 NO           NO       4 From 10     2 From 10
# Patiant-03                YES           NO       6 From 10     5 From 10
# Patiant-04                 NO           NO       3 From 10     2 From 10
# Patiant-05                YES          YES       5 From 10     5 From 10
#
#                 Optimisim Expert Diagnose
# Patient Number
# Patiant-01      4 From 10  Bipolar Type-2
# Patiant-02      5 From 10      Depression
# Patiant-03      7 From 10  Bipolar Type-1
# Patiant-04      2 From 10  Bipolar Type-2
# Patiant-05      6 From 10          Normal

# %%
disorder.shape
# Out:
# (120, 18)

# %% [markdown]
# There are total 120 objeservations and 18 features.

# %%
disorder.describe().T
# Out:
#                     count unique             top freq
# Sadness               120      4         Usually   42
# Euphoric              120      4          Seldom   46
# Exhausted             117      4       Sometimes   35
# Sleep dissorder       116      4       Sometimes   40
# Mood Swing            120      2              NO   63
# Suicidal thoughts     120      3              NO   63
# Anorxia               118      2              NO   72
# Authority Respect     114      2              NO   67
# Try-Explanation       120      2              NO   63
# Aggressive Response   120      2              NO   62
# Ignore & Move-On      113      2              NO   63
# Nervous Break-down    120      2             YES   62
# Admit Mistakes        114      2              NO   61
# Overthinking          119      2             YES   64
# Sexual Activity       120      9       5 From 10   22
# Concentration         120      8       4 From 10   33
# Optimisim             120      9       6 From 10   21
# Expert Diagnose       120      4  Bipolar Type-2   31

# %%
disorder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, Patiant-01 to Patiant-120
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sadness              120 non-null    object
#  1   Euphoric             120 non-null    object
#  2   Exhausted            117 non-null    object
#  3   Sleep dissorder      116 non-null    object
#  4   Mood Swing           120 non-null    object
#  5   Suicidal thoughts    120 non-null    object
#  6   Anorxia              118 non-null    object
#  7   Authority Respect    114 non-null    object
#  8   Try-Explanation      120 non-null    object
#  9   Aggressive Response  120 non-null    object
#  10  Ignore & Move-On     113 non-null    object
#  11  Nervous Break-down   120 non-null    object
#  12  Admit Mistakes       114 non-null    object
#  13  Overthinking         119 non-null    object
#  14  Sexual Activity      120 non-null    object
#  15  Concentration        120 non-null    object
#  16  Optimisim            120 non-null    object
#  17  Expert Diagnose      120 non-null    object
# dtypes: object(18)
# memory usage: 17.8+ KB

# %% [markdown]
# All the columns are of object types.

# %%
disorder.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate row is present.

# %% [markdown]
# # Data Cleaning

# %%
disorder.rename(columns={'Sleep dissorder':'Sleep disorder','Anorxia':'Anorexia','Optimisim':'Optimism'},inplace=True)

# %%
disorder['Expert Diagnose'].value_counts()
# Out:
# Bipolar Type-2    31
# Depression        31
# Normal            30
# Bipolar Type-1    28
# Name: Expert Diagnose, dtype: int64

# %% [markdown]
# The dataset is balanced.

# %%
disorder.isnull().sum()
# Out:
# Sadness                0
# Euphoric               0
# Exhausted              3
# Sleep dissorder        4
# Mood Swing             0
# Suicidal thoughts      0
# Anorxia                2
# Authority Respect      6
# Try-Explanation        0
# Aggressive Response    0
# Ignore & Move-On       7
# Nervous Break-down     0
# Admit Mistakes         6
# Overthinking           1
# Sexual Activity        0
# Concentration          0
# Optimisim              0
# Expert Diagnose        0
# dtype: int64

# %% [markdown]
# Some columns have a few null values. Let us treat them first

# %% [markdown]
# **Cal % of null values**

# %%
print("Percent of missing data: %.2f" % ((np.sum(disorder.isnull().any())/len(disorder))*100),'%')
# Out:
# Percent of missing data: 5.83 %

# %%
null_col = [col for col in disorder.columns if disorder[col].isnull().any()]

for col in null_col:
    disorder[col] = disorder[col].fillna(disorder[col].mode()[0])

# %%
for col in disorder.columns:
    print(col)
    print(disorder[col].value_counts())
# Out:
# Sadness
# Usually       42
# Sometimes     42
# Most-Often    20
# Seldom        16
# Name: Sadness, dtype: int64
# Euphoric
# Seldom        46
# Sometimes     45
# Usually       20
# Most-Often     9
# Name: Euphoric, dtype: int64
# Exhausted
# Sometimes     38
# Usually       34
# Most-Often    30
# Seldom        18
# Name: Exhausted, dtype: int64
# Sleep disorder
# Sometimes     44
# Usually       34
# Most-Often    21
# Seldom        21
# Name: Sleep disorder, dtype: int64
# Mood Swing
# NO     63
# YES    57
# Name: Mood Swing, dtype: int64
# Suicidal thoughts
# NO      63
# YES     56
# YES      1
# Name: Suicidal thoughts, dtype: int64
# Anorexia
# NO     74
# YES    46
# Name: Anorexia, dtype: int64
# Authority Respect
# NO     73
# YES    47
# Name: Authority Respect, dtype: int64
# Try-Explanation
# NO     63
# YES    57
# Name: Try-Explanation, dtype: int64
# Aggressive Response
# NO     62
# YES    58
# Name: Aggressive Response, dtype: int64
# Ignore & Move-On
# NO     70
# YES    50
# Name: Ignore & Move-On, dtype: int64
# Nervous Break-down
# YES    62
# NO     58
# Name: Nervous Break-down, dtype: int64
# Admit Mistakes
# NO     67
# YES    53
# Name: Admit Mistakes, dtype: int64
# Overthinking
# YES    65
# NO     55
# Name: Overthinking, dtype: int64
# Sexual Activity
# 5 From 10    22
# 4 From 10    20
# 3 From 10    17
# 6 From 10    15
# 2 From 10    15
# 7 From 10    14
# 8 From 10    11
# 1 From 10     4
# 9 From 10     2
# Name: Sexual Activity, dtype: int64
# Concentration
# 4 From 10    33
# 2 From 10    21
# 5 From 10    21
# 7 From 10    14
# 3 From 10    12
# 6 From 10    10
# 1 From 10     5
# 8 From 10     4
# Name: Concentration, dtype: int64
# Optimism
# 6 From 10    21
# 5 From 10    20
# 4 From 10    19
# 2 From 10    18
# 3 From 10    18
# 7 From 10     8
# 8 From 10     8
# 1 From 10     6
# 9 From 10     2
# Name: Optimism, dtype: int64
# Expert Diagnose
# Bipolar Type-2    31
# Depression        31
# Normal            30
# Bipolar Type-1    28
# Name: Expert Diagnose, dtype: int64

# %% [markdown]
# Suicidal thoughts have two values for yes. We need to handle it.

# %%
disorder.loc[:,'Suicidal thoughts'] = disorder.loc[:,'Suicidal thoughts'].str.strip()

disorder['Suicidal thoughts'].value_counts()
# Out:
# NO     63
# YES    57
# Name: Suicidal thoughts, dtype: int64

# %%
for j in range(14,17):
    for i in range(len(disorder)):
        disorder.iloc[i,j] = int(disorder.iloc[i,j][0])

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Distributions of columns

# %%
fig, axes = plt.subplots(5, 3, figsize=(20, 25))
axes = axes.flatten()

for i, col in enumerate(disorder.columns[:14]):
    axes[i].pie(disorder[col].value_counts(),autopct='%.2f',textprops = {'color':'white', 'fontsize':12, 'fontweight':'bold'},shadow=True)
    axes[i].set_title(col,fontweight='bold')
    axes[i].legend(disorder[col].value_counts().index)

fig.delaxes(axes[14])
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 5))
axes = axes.flatten()

for i, col in enumerate(disorder.columns[14:17]):
    sns.barplot(x=disorder[col].value_counts().index,y=disorder[col].value_counts(),ax=axes[i],color='blue',edgecolor='black')
    axes[i].set_title(col,fontweight='bold')



plt.tight_layout()
plt.show()

# %%
sns.countplot(x = 'Sadness', hue = 'Expert Diagnose', data = disorder, palette = 'viridis')
plt.title('Distribution of Sadness for Each Expert Diagnose Level')
plt.xlabel('Sadness')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Sadder the patient, more likely to suffer from a mental disorder.

# %%
plt.figure(figsize=(10, 6))

sns.barplot(y = 'Optimism', x = 'Concentration', hue = 'Expert Diagnose', data = disorder, errorbar = None, palette = 'viridis')
plt.title('Relationship between Optimism and Concentration')
plt.xlabel('Concentration')
plt.ylabel('Optimism')

# place the legend at the top-right corner of the plot, outside the plot area
plt.legend(title = 'Expert Diagnose', bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# Patients with high optimism and concentration are less prone to mental disorders.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Converting categorical to numerical values

# %%
# columns: Sadness, Euphoric,Exhausted,Sleep Disorder
disorder = disorder.replace({'Seldom':1,'Sometimes':2,'Usually':3,'Most-Often':4})

# columns: Mood swings,Suicidal thoughts,Anorexia,Authority Respect, Try-Explanation,
# Aggressive Response,Ignore & Move-On, Nervous Break-down,Admit Mistakes,Overthinking
disorder = disorder.replace({'YES':1,'NO':0})

# columns: Expert Diagnose
disorder = disorder.replace({'Normal':0,'Depression':1,'Bipolar Type-2':2,'Bipolar Type-1':3})

# %%
disorder.head()
# Out:
#                 Sadness  Euphoric  Exhausted  Sleep disorder  Mood Swing  \
# Patient Number
# Patiant-01            3         1          2               2           1
# Patiant-02            3         1          3               2           0
# Patiant-03            2         4          2               2           1
# Patiant-04            3         1          3               4           1
# Patiant-05            3         3          2               2           0
#
#                 Suicidal thoughts  Anorexia  Authority Respect  \
# Patient Number
# Patiant-01                      1         0                  0
# Patiant-02                      1         0                  0
# Patiant-03                      0         0                  0
# Patiant-04                      1         1                  0
# Patiant-05                      0         0                  0
#
#                 Try-Explanation  Aggressive Response  Ignore & Move-On  \
# Patient Number
# Patiant-01                    1                    0                 0
# Patiant-02                    0                    0                 0
# Patiant-03                    1                    1                 0
# Patiant-04                    1                    0                 0
# Patiant-05                    0                    0                 0
#
#                 Nervous Break-down  Admit Mistakes  Overthinking  \
# Patient Number
# Patiant-01                       1               1             1
# Patiant-02                       0               0             0
# Patiant-03                       1               1             0
# Patiant-04                       0               0             0
# Patiant-05                       1               1             1
#
#                 Sexual Activity  Concentration  Optimism  Expert Diagnose
# Patient Number
# Patiant-01                    3              3         4                2
# Patiant-02                    4              2         5                1
# Patiant-03                    6              5         7                3
# Patiant-04                    3              2         2                2
# Patiant-05                    5              5         6                0

# %% [markdown]
# ## Checking Correlation

# %%
corr = disorder.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ## Detecting Outliers

# %%
fig, axes = plt.subplots(6, 3, figsize=(20, 25))
axes = axes.flatten()

for i, col in enumerate(disorder.columns):
    sns.boxplot(disorder[col],ax=axes[i])
    axes[i].set_title(col,fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## PCA

# %%
X = disorder.drop('Expert Diagnose',axis=1)
y = disorder['Expert Diagnose']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)

pca_data = pca.fit_transform(X_scaled)

pca_data = np.vstack((pca_data.T,y)).T

pca_df = pd.DataFrame(data=pca_data,columns=('1st_principal','2nd_principal','labels'))

sns.scatterplot(data=pca_df,x='1st_principal',y='2nd_principal',hue='labels')
plt.show()

# %%
pca.n_components = 17
pca_data = pca.fit_transform(X_scaled)
percentage_var_explained = pca.explained_variance_/np.sum(pca.explained_variance_)
cum_var_explained = np.cumsum(percentage_var_explained)

plt.plot(cum_var_explained,linewidth=1)
plt.title('Explained Variance')
plt.xlabel('Components')
plt.ylabel('Cummulative Explained Variance')
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# # Model Training

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,train_size=0.7,random_state=SEED)

# %%
print('Shape of train dataset:', X_train.shape)
print('Shape of test dataset:', X_test.shape)
# Out:
# Shape of train dataset: (84, 17)
# Shape of test dataset: (36, 17)

# %%
print('Value count of y_train')
print(y_train.value_counts(),'\n')

print('Value count of y_test')
print(y_test.value_counts())
# Out:
# Value count of y_train
# 2    21
# 1    21
# 0    21
# 3    21
# Name: Expert Diagnose, dtype: int64
#
# Value count of y_test
# 2    10
# 1    10
# 0     9
# 3     7
# Name: Expert Diagnose, dtype: int64

# %%
smote = RandomOverSampler()
X_train,y_train = smote.fit_resample(X_train,y_train)

# %%
def score_check(y_true,y_pred):
    print('Accuracy of the model:',accuracy_score(y_true,y_pred))
    print('Precision of the model:',precision_score(y_true,y_pred,average='macro'))
    print('Recall of the model:',recall_score(y_true,y_pred,average='macro'))
    print('Classification Report:\n\n',classification_report(y_true,y_pred))

# %%
def display_matrix(y_true,y_pred,model):
    cm = confusion_matrix(y_true,y_pred,labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
    disp.plot()
    plt.show()

# %% [markdown]
# ## Base Models

# %% [markdown]
# ### Logistic Regression

# %%
logistic_regression = LogisticRegression(random_state=SEED)
logistic_regression.fit(X_train,y_train)
y_pred = logistic_regression.predict(X_test)
lr_accuracy = accuracy_score(y_test,y_pred)

# %%
score_check(y_test,y_pred)
# Out:
# Accuracy of the model: 0.8611111111111112
# Precision of the model: 0.8819444444444444
# Recall of the model: 0.875
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         9
#            1       1.00      0.70      0.82        10
#            2       1.00      0.80      0.89        10
#            3       0.78      1.00      0.88         7
#
#     accuracy                           0.86        36
#    macro avg       0.88      0.88      0.86        36
# weighted avg       0.89      0.86      0.86        36

# %%
display_matrix(y_test,y_pred,logistic_regression)

# %% [markdown]
# ### Support Vector Classifier

# %%
svc = SVC(random_state=SEED)
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
svc_accuracy = accuracy_score(y_test,y_pred)

# %%
score_check(y_test,y_pred)
# Out:
# Accuracy of the model: 0.8611111111111112
# Precision of the model: 0.8795454545454546
# Recall of the model: 0.875
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90         9
#            1       1.00      0.80      0.89        10
#            2       1.00      0.70      0.82        10
#            3       0.70      1.00      0.82         7
#
#     accuracy                           0.86        36
#    macro avg       0.88      0.88      0.86        36
# weighted avg       0.90      0.86      0.86        36

# %%
display_matrix(y_test,y_pred,svc)

# %% [markdown]
# ### KNN

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
knn_accuracy = accuracy_score(y_test,y_pred)

# %%
score_check(y_test,y_pred)
# Out:
# Accuracy of the model: 0.8055555555555556
# Precision of the model: 0.825
# Recall of the model: 0.8142857142857143
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         9
#            1       0.80      0.80      0.80        10
#            2       1.00      0.60      0.75        10
#            3       0.75      0.86      0.80         7
#
#     accuracy                           0.81        36
#    macro avg       0.82      0.81      0.80        36
# weighted avg       0.83      0.81      0.80        36

# %%
display_matrix(y_test,y_pred,knn)

# %% [markdown]
# ### Random Forest

# %%
random_forest = RandomForestClassifier(random_state=SEED)
random_forest.fit(X_train,y_train)
y_pred = random_forest.predict(X_test)
rf_accuracy = accuracy_score(y_test,y_pred)

# %%
score_check(y_test,y_pred)
# Out:
# Accuracy of the model: 0.9166666666666666
# Precision of the model: 0.9232954545454546
# Recall of the model: 0.925
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90         9
#            1       1.00      0.80      0.89        10
#            2       1.00      0.90      0.95        10
#            3       0.88      1.00      0.93         7
#
#     accuracy                           0.92        36
#    macro avg       0.92      0.93      0.92        36
# weighted avg       0.93      0.92      0.92        36

# %%
display_matrix(y_test,y_pred,random_forest)

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### Logistic Regression

# %%
parameters = {'penalty': ['l1', 'l2', 'elasticnet', 'none'],
              'tol':[1e-4,1e-3,1e-2,1e-1,1e-0,1e1,1e2,1e3,1e4],
              'C':np.logspace(-5,5,20),
              'solver' : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
              'max_iter':[100,500,1000,1500,2000,2500],
              'multi_class' : ['auto', 'ovr', 'multinomial']
             }

log_clf = GridSearchCV(logistic_regression,param_grid=parameters,cv=5,verbose=True,n_jobs=-1,scoring='accuracy')

# %%
best_log_reg = log_clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 64800 candidates, totalling 324000 fits

# %%
best_log_reg.best_estimator_
# Out:
# LogisticRegression(C=20.6913808111479, penalty='l1', random_state=7,
#                    solver='liblinear')

# %%
y_pred = best_log_reg.predict(X_test)
best_lr_accuracy = accuracy_score(y_test,y_pred)

# %%
score_check(y_test,y_pred)
# Out:
# Accuracy of the model: 0.8888888888888888
# Precision of the model: 0.90625
# Recall of the model: 0.9
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         9
#            1       1.00      0.70      0.82        10
#            2       1.00      0.90      0.95        10
#            3       0.88      1.00      0.93         7
#
#     accuracy                           0.89        36
#    macro avg       0.91      0.90      0.89        36
# weighted avg       0.91      0.89      0.89        36

# %%
display_matrix(y_test,y_pred,best_log_reg)

# %% [markdown]
# ### Random Forest

# %%
parameters = {'n_estimators':[int(x) for x in np.linspace(10,100,20)],
              'criterion':["gini", "entropy", "log_loss"],
              'max_depth':list(range(2,11)),
              'min_samples_split':[2,5,7],
              'max_features':["sqrt", "log2", None],
              'min_samples_leaf':[1,2],
              'bootstrap':[True,False]
             }
rf_clf = RandomizedSearchCV(random_forest,param_distributions=parameters,cv=5,verbose=True,n_jobs=-1,random_state=SEED,scoring='accuracy')

# %%
best_rf_clf = rf_clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
best_rf_clf.best_estimator_
# Out:
# RandomForestClassifier(max_depth=4, max_features='log2', min_samples_leaf=2,
#                        random_state=7)

# %%
y_pred = best_rf_clf.predict(X_test)
best_rf_accuracy = accuracy_score(y_test,y_pred)

# %%
score_check(y_test,y_pred)
# Out:
# Accuracy of the model: 0.9444444444444444
# Precision of the model: 0.94375
# Recall of the model: 0.95
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95         9
#            1       1.00      0.90      0.95        10
#            2       1.00      0.90      0.95        10
#            3       0.88      1.00      0.93         7
#
#     accuracy                           0.94        36
#    macro avg       0.94      0.95      0.94        36
# weighted avg       0.95      0.94      0.94        36

# %%
display_matrix(y_test,y_pred,best_rf_clf)

# %% [markdown]
# Hyperparameter tuning is making the model to overfit.

# %% [markdown]
# ## Neural Network

# %%
nn_model = Sequential([
    Dense(512, activation='tanh', input_shape=(X_train.shape[1],)),
    Dropout(rate=0.1),
    Dense(512, activation='tanh'),
    Dense(512, activation='tanh'),
    Dense(4, activation='softmax')
])

# %%
nn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history=nn_model.fit(X_train,y_train,epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8800 - accuracy: 0.6429
# Epoch 2/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2745 - accuracy: 0.9048
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1243 - accuracy: 0.9524
# Epoch 4/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0996 - accuracy: 0.9524
# Epoch 5/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0578 - accuracy: 0.9762
# Epoch 6/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 10/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 11/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 12/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 13/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 14/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 16/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 17/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 18/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 19/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 20/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 21/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 22/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 23/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 24/100
# 3/3 [==============================] - 0s 4ms/step - loss: 8.7532e-04 - accuracy: 1.0000
# Epoch 25/100
# 3/3 [==============================] - 0s 4ms/step - loss: 9.5258e-04 - accuracy: 1.0000
# Epoch 26/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 27/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 28/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.8676e-04 - accuracy: 1.0000
# Epoch 29/100
# 3/3 [==============================] - 0s 3ms/step - loss: 8.2018e-04 - accuracy: 1.0000
# Epoch 30/100
# 3/3 [==============================] - 0s 5ms/step - loss: 5.5782e-04 - accuracy: 1.0000
# Epoch 31/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.2143e-04 - accuracy: 1.0000
# Epoch 32/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 33/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.3081e-04 - accuracy: 1.0000
# Epoch 34/100
# 3/3 [==============================] - 0s 4ms/step - loss: 8.3738e-04 - accuracy: 1.0000
# Epoch 35/100
# 3/3 [==============================] - 0s 4ms/step - loss: 8.3742e-04 - accuracy: 1.0000
# Epoch 36/100
# 3/3 [==============================] - 0s 4ms/step - loss: 6.6894e-04 - accuracy: 1.0000
# Epoch 37/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.2095e-04 - accuracy: 1.0000
# Epoch 38/100
# 3/3 [==============================] - 0s 4ms/step - loss: 7.1579e-04 - accuracy: 1.0000
# Epoch 39/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.3226e-04 - accuracy: 1.0000
# Epoch 40/100
# 3/3 [==============================] - 0s 4ms/step - loss: 5.5485e-04 - accuracy: 1.0000
# Epoch 41/100
# 3/3 [==============================] - 0s 5ms/step - loss: 5.3788e-04 - accuracy: 1.0000
# Epoch 42/100
# 3/3 [==============================] - 0s 5ms/step - loss: 4.7222e-04 - accuracy: 1.0000
# Epoch 43/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.1044e-04 - accuracy: 1.0000
# Epoch 44/100
# 3/3 [==============================] - 0s 5ms/step - loss: 4.6233e-04 - accuracy: 1.0000
# Epoch 45/100
# 3/3 [==============================] - 0s 4ms/step - loss: 6.0936e-04 - accuracy: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 0s 6ms/step - loss: 4.3217e-04 - accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.3334e-04 - accuracy: 1.0000
# Epoch 48/100
# 3/3 [==============================] - 0s 5ms/step - loss: 4.6698e-04 - accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 0s 4ms/step - loss: 5.1623e-04 - accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.8525e-04 - accuracy: 1.0000
# Epoch 51/100
# 3/3 [==============================] - 0s 5ms/step - loss: 4.1392e-04 - accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 3.2736e-04 - accuracy: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.8585e-04 - accuracy: 1.0000
# Epoch 54/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.7361e-04 - accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.3729e-04 - accuracy: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 0s 5ms/step - loss: 3.2712e-04 - accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.3494e-04 - accuracy: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 0s 6ms/step - loss: 3.4410e-04 - accuracy: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.2548e-04 - accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.9968e-04 - accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.3939e-04 - accuracy: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.2185e-04 - accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.6532e-04 - accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.1742e-04 - accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7871e-04 - accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 3ms/step - loss: 3.0910e-04 - accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.8523e-04 - accuracy: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 5ms/step - loss: 3.2914e-04 - accuracy: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.8278e-04 - accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.0163e-04 - accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5943e-04 - accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 6ms/step - loss: 3.9687e-04 - accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.0647e-04 - accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 5ms/step - loss: 3.1157e-04 - accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 5ms/step - loss: 3.2720e-04 - accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.3403e-04 - accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2561e-04 - accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5121e-04 - accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2137e-04 - accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.2547e-04 - accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6624e-04 - accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4428e-04 - accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6947e-04 - accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6046e-04 - accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 2.9976e-04 - accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.1085e-04 - accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7051e-04 - accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1940e-04 - accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4319e-04 - accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0844e-04 - accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6149e-04 - accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6778e-04 - accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6272e-04 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8455e-04 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5178e-04 - accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6320e-04 - accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.5972e-04 - accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7907e-04 - accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6850e-04 - accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9280e-04 - accuracy: 1.0000

# %%
y_pred = nn_model.predict(X_test)
y_pred_mlp = np.argmax(y_pred, axis=1)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
nn_accuracy = list(nn_model.evaluate(X_test,y_test))[1]
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0261 - accuracy: 0.8889

# %%
score_check(y_test,y_pred_mlp)
# Out:
# Accuracy of the model: 0.8888888888888888
# Precision of the model: 0.90625
# Recall of the model: 0.9
# Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         9
#            1       1.00      0.70      0.82        10
#            2       1.00      0.90      0.95        10
#            3       0.88      1.00      0.93         7
#
#     accuracy                           0.89        36
#    macro avg       0.91      0.90      0.89        36
# weighted avg       0.91      0.89      0.89        36

# %%
models = pd.DataFrame({'Models':['Logistic Regression','Support Vector Classifier','K-Nearest Neighborhood','Random Forest Classifier', 
                                 'Logistic Regression(tuned)','Random Forest(tuned)','Neural Network'],
                       'Accuracy':[lr_accuracy,svc_accuracy,knn_accuracy,rf_accuracy,best_lr_accuracy,best_rf_accuracy,nn_accuracy]})

display(models.sort_values(by='Accuracy',ascending=False))
# Out:
#                        Models  Accuracy
# 5        Random Forest(tuned)  0.944444
# 3    Random Forest Classifier  0.916667
# 6              Neural Network  0.888889
# 4  Logistic Regression(tuned)  0.888889
# 0         Logistic Regression  0.861111
# 1   Support Vector Classifier  0.861111
# 2      K-Nearest Neighborhood  0.805556

# %%
with open('ANN_model.pkl', 'wb') as file:
    # Serialize the model and write it to the file
    pickle.dump(nn_model, file)
# Out:
# INFO:tensorflow:Assets written to: ram://95770809-5539-434b-8eec-3a30d9a4c39b/assets
